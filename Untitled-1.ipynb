# %%
numbers = [1, 2, 3, 4, 5]

# %%
numbers = [1, 2, 3, 4, 5]
numbers[2]
# Out:
# 3

# %%
food = ["pizza", "fries", "fruits", "cake"]
food[0] = "fried chicken"
print(food)
# Out:
# ['fried chicken', 'fries', 'fruits', 'cake']

# %%
numbers = [1, 2, 3, 4, 5]
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
fruits = ["mango", "banana", "watermelon"]
fruits.insert(1, "orange")
print(fruits)
# Out:
# ['mango', 'orange', 'banana', 'watermelon']

# %%
foods = ["fries", "burger", "pancake", "noodles"]
foods.remove("noodles")

numbers = [1, 2, 3, 4, 5]
numbers.remove(3)

print(foods)
print(numbers)
# Out:
# ['fries', 'burger', 'pancake']
# [1, 2, 4, 5]

# %%
numbers = [4, 2, 5, 1, 3]
numbers.sort()
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers = [4, 2, 5, 1, 3]
sorted(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
fruits = ["apple", "strawberry", "tomato", "mango", "watermelon"]
fruits[0:5:2]
# Out:
# ['apple', 'tomato', 'watermelon']

# %%
numbers = (1, 2, 3, 4, 5)
print(numbers)
# Out:
# (1, 2, 3, 4, 5)
